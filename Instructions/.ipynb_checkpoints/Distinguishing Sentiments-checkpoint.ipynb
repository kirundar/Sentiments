# %% [markdown]
# ## Unit 7 | Assignment - Distinguishing Sentiments
#
# ## Background
#
# __Twitter__ has become a wildly sprawling jungle of information&mdash;140 characters at a time. Somewhere between 350 million and 500 million tweets are estimated to be sent out _per day_. With such an explosion of data, on Twitter and elsewhere, it becomes more important than ever to tame it in some way, to concisely capture the essence of the data.
#
# Choose __one__ of the following two assignments, in which you will do just that. Good luck!
#
# ## News Mood
#
# In this assignment, you'll create a Python script to perform a sentiment analysis of the Twitter activity of various news oulets, and to present your findings visually.
#
# Your final output should provide a visualized summary of the sentiments expressed in Tweets sent out by the following news organizations: __BBC, CBS, CNN, Fox, and New York times__.
#
# ![output_10_0.png](output_10_0.png)
#
# ![output_13_1.png](output_13_1.png)
#
# The first plot will be and/or feature the following:
#
# * Be a scatter plot of sentiments of the last __100__ tweets sent out by each news organization, ranging from -1.0 to 1.0, where a score of 0 expresses a neutral sentiment, -1 the most negative sentiment possible, and +1 the most positive sentiment possible.
# * Each plot point will reflect the _compound_ sentiment of a tweet.
# * Sort each plot point by its relative timestamp.
#
# The second plot will be a bar plot visualizing the _overall_ sentiments of the last 100 tweets from each organization. For this plot, you will again aggregate the compound sentiments analyzed by VADER.
#
# The tools of the trade you will need for your task as a data analyst include the following: tweepy, pandas, matplotlib, seaborn, textblob, and VADER.
#
# Your final Jupyter notebook must:
#
# * Pull last 100 tweets from each outlet.
# * Perform a sentiment analysis with the compound, positive, neutral, and negative scoring for each tweet.
# * Pull into a DataFrame the tweet's source acount, its text, its date, and its compound, positive, neutral, and negative sentiment scores.
# * Export the data in the DataFrame into a CSV file.
# * Save PNG images for each plot.
#
# As final considerations:
#
# * Use the Matplotlib and Seaborn libraries.
# * Include a written description of three observable trends based on the data.
# * Include proper labeling of your plots, including plot titles (with date of analysis) and axes labels.
# * Include an exported markdown version of your Notebook called  `README.md` in your GitHub repository.
#
#
# ## PlotBot
#
# In this activity, more challenging than the last, you will build a Twitter bot that sends out visualized sentiment analysis of a Twitter account's recent tweets.
#
# Visit [https://twitter.com/PlotBot5](https://twitter.com/PlotBot5) for an example of what your script should do.
#
# The bot receives tweets via mentions and in turn performs sentiment analysis on the most recent twitter account specified in the mention
#
# For example, when a user tweets, __"@PlotBot Analyze: @CNN,"__ it will trigger a sentiment analysis on the CNN twitter feed.
#
# A plot from the sentiment analysis is then tweeted to the PlotBot5 twitter feed. See below for examples of scatter plots you will generate:
#
# ![@juanitasoranno.png](@juanitasoranno.png)
# ![@nancypwong.png](@nancypwong.png)
# ![nytimes.png](nytimes.png)
#
#
# Hints, requirements, and considerations:
#
# * Your bot should scan your account every __five minutes__ for mentions.
# * Your bot should pull 500 most recent tweets to analyze for each incoming request.
# * Your script should prevent abuse by analyzing __only__ Twitter accounts that have not previously been analyzed.
# * Your plot should include meaningful legend and labels.
# * It should also mention the Twitter account name of the requesting user.
# * When submitting your assignment, be sure to have at least __three__ analyses tweeted out from your account (enlist the help of classmates, friends, or family, if necessary!).
# * Notable libraries used to complete this application include: Matplotlib, Pandas, Tweepy, TextBlob, and Seaborn.
# * You may find it helpful to organize your code in function(s), then call them.
# * If you're not yet familiar with creating functions in Python, here is a tutorial you may wish to consult: [https://www.tutorialspoint.com/python/python_functions.htm](https://www.tutorialspoint.com/python/python_functions.htm).
#
#
#
# ## Copyright
#
# Coding Boot Camp (C) 2017. All Rights Reserved./

# %%
import matplotlib.pyplot as plt
import requests as req
import pandas as pd
import tweepy
import json
import seaborn as sns
import matplotlib.patches as mpatches
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
consumer_key = 'typOrUhmTbPbSflEaIkWD7ju9'
consumer_secret = 'whdF61hRT5ra5AkthAeSbH8tkSALX3eZVOYudUFMbXYaC31O56'
access_token = '1410770743-aDGtwuJT3jTXzQD1bu4qQM9hrVllgKkFZRB9mbc'
access_token_secret = 'PMcFAAlEr621QiXZ1QJjVLRaYAoardlNzqu9p9FeyWP21'

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
news_networks = ["@CNN","@FoxNews","@BBC","@NYT","@CBS"]

# %%
news = []
account =[]
date = []
text =[]
tweet_number=[]
compound_list = []
positive_list = []
negative_list = []
neutral_list = []
for network in news_networks:
    public_tweets = api.search(network, count=100, result_type="recent")
    for tweet in public_tweets['statuses']:
        compound = analyzer.polarity_scores(tweet["text"])["compound"]
        pos = analyzer.polarity_scores(tweet["text"])["pos"]
        neu = analyzer.polarity_scores(tweet["text"])["neu"]
        neg = analyzer.polarity_scores(tweet["text"])["neg"]
        news.append(network)
        account.append(tweet['user']['name'])
        date.append(tweet['created_at'])
        text.append(tweet['text'])
        compound_list.append(compound)
        positive_list.append(pos)
        negative_list.append(neg)
        neutral_list.append(neu)

# %%
#create the data frame
df = pd.DataFrame({
    "Network":news,
    "User":account,
    "Date":date,
    "Text":text,
    "Positive":positive_list,
    "Neutral":neutral_list,
    "Negative":negative_list,
    "Compound":compound_list,
})
df = df[['Network','User','Date','Text','Positive','Neutral','Negative','Compound']]

# %%
df.to_csv("Twitter_Sentiments.csv")
df = df.sort_values("Date")
df
# Out:
#       Network                  User                            Date  \
# 399      @NYT           Labi Siffre  Tue Oct 31 19:18:48 +0000 2017
# 398      @NYT           ☂️skyfish☂️  Tue Oct 31 19:21:21 +0000 2017
# 397      @NYT    SicSemp for Senate  Tue Oct 31 19:34:00 +0000 2017
# 396      @NYT          NoMoreGames®  Tue Oct 31 19:43:11 +0000 2017
# 395      @NYT                 EmBee  Tue Oct 31 19:43:23 +0000 2017
# 394      @NYT   Green-Diversity.com  Tue Oct 31 19:43:34 +0000 2017
# 393      @NYT  Jose Tijam, PMP, CSM  Tue Oct 31 19:46:18 +0000 2017
# 392      @NYT    Melinda Mae Miller  Tue Oct 31 19:46:26 +0000 2017
# 391      @NYT              Jeremias  Tue Oct 31 19:52:30 +0000 2017
# 390      @NYT           Gitmo Watch  Tue Oct 31 19:52:39 +0000 2017
# 389      @NYT   Green-Diversity.com  Tue Oct 31 19:53:00 +0000 2017
# 388      @NYT   Green-Diversity.com  Tue Oct 31 19:59:46 +0000 2017
# 387      @NYT             Saul Good  Tue Oct 31 20:05:18 +0000 2017
# 386      @NYT  Jose Tijam, PMP, CSM  Tue Oct 31 20:05:21 +0000 2017
# 385      @NYT           Klaus Riede  Tue Oct 31 20:11:29 +0000 2017
# 384      @NYT       Lynn Petronella  Tue Oct 31 20:25:01 +0000 2017
# 383      @NYT       Andrea Mitchell  Tue Oct 31 20:28:04 +0000 2017
# 382      @NYT         Carolyn Craig  Tue Oct 31 20:28:16 +0000 2017
# 381      @NYT            Sean Sasso  Tue Oct 31 20:28:31 +0000 2017
# 380      @NYT         Steve Warwick  Tue Oct 31 20:30:06 +0000 2017
# 379      @NYT           james kacer  Tue Oct 31 20:32:38 +0000 2017
# 378      @NYT         IamUSAProudRU  Tue Oct 31 20:32:59 +0000 2017
# 377      @NYT         Jennifer Pike  Tue Oct 31 20:32:59 +0000 2017
# 376      @NYT              Mo Kelly  Tue Oct 31 20:34:00 +0000 2017
# 375      @NYT                @marie  Tue Oct 31 20:34:53 +0000 2017
# 374      @NYT                 hbhat  Tue Oct 31 20:36:08 +0000 2017
# 373      @NYT            Meg Murray  Tue Oct 31 20:36:49 +0000 2017
# 372      @NYT       Jean M. O'Brien  Tue Oct 31 20:49:48 +0000 2017
# 371      @NYT       Alka Pradhan 🇺🇸  Tue Oct 31 20:49:58 +0000 2017
# 370      @NYT        Paul Bartolini  Tue Oct 31 20:50:48 +0000 2017
# ..        ...                   ...                             ...
# 117  @FoxNews               CTmommy  Wed Nov 01 04:01:44 +0000 2017
# 116  @FoxNews               Banshee  Wed Nov 01 04:01:44 +0000 2017
RT @NYT: Why Papadapoulos? Decoding Mueller’s ...     0.143    0.857
# 382  RT @NYT: Why Papadapoulos? Decoding Mueller’s ...     0.143    0.857
# 381  "Recent Commercial Real Estate Transactions" v...     0.000    1.000
# 380  RT @NYT: Why Papadapoulos? Decoding Mueller’s ...     0.143    0.857
# 379  @NYT @mitchellreports Manafort = Podesta = Cli...     0.000    1.000
# 378  @johnpodesta @WSJ @thehill @NYT @washingtonpos...     0.000    0.529
# 377  RT @NYT: Why Papadapoulos? Decoding Mueller’s ...     0.143    0.857
# 376  RT @NYT: Why Papadapoulos? Decoding Mueller’s ...     0.143    0.857
# 375  RT @NYT: Why Papadapoulos? Decoding Mueller’s ...     0.143    0.857
# 374  RT @NYT: Why Papadapoulos? Decoding Mueller’s ...     0.143    0.857
# 373  RT @NYT: Why Papadapoulos? Decoding Mueller’s ...     0.143    0.857
# 372  RT @NYT: Why Papadapoulos? Decoding Mueller’s ...     0.143    0.857
# 371  RT @GitmoWatch: @MiddleEastEye @AlJazeera @nyt...     0.000    1.000
# 370  RT @NYT: Why Papadapoulos? Decoding Mueller’s ...     0.143    0.857
# ..                                                 ...       ...      ...
# 117  RT @FoxNews: .@IngrahamAngle: We shouldn't los...     0.106    0.894
# 116  RT @FoxNews: .@marklevinshow on U.S. gov't vet...     0.000    0.896
# 119  RT @FoxNews: "I refuse to live in fear" The NY...     0.000    0.565
# 10   RT @CNN: Paul Manafort has 3 US passports and ...     0.000    0.866
# 9    RT @WalshFreedom: @CNN is lying again. They ke...     0.062    0.623
# 8    RT @LauraLoomer: This is why I shut @andersonc...     0.000    1.000
# 115                    @informationplz_ @FoxNews Right     0.000    1.000
# 114  RT @TuckerCarlson: .@brithume: These kinds of ...     0.000    0.828
# 113  @amagrammie @RuthieRedSox @He_Has_Failed @mich...     0.000    1.000
# 7    RT @CNN: Fact check: Team Trump uses misinform...     0.000    0.881
# 111  @JudgeJeanine @FoxNews it's funny she wrote an...     0.132    0.868
# 110  RT @FoxNews: .@IngrahamAngle: We shouldn't los...     0.106    0.894
# 6    RT @CNN: US Supreme Court Justice Ruth Bader G...     0.350    0.650
# 112  RT @AKMMitchell: .@seanhannity and @TuckerCarl...     0.000    1.000
# 109  @jrasmussbbn @tsykes8888 @seanhannity @FoxNews...     0.116    0.684
# 108  RT @FoxNews: .@IngrahamAngle: We shouldn't los...     0.106    0.894
# 107  RT @FoxNews: OPINION: New York terror attack -...     0.055    0.682
# 5    RT @CNN: Paul Manafort has 3 US passports and ...     0.000    0.866
# 106  @FoxNews @IngrahamAngle That is absolutely cor...     0.000    1.000
# 4    RT @CNN: Former National Security Council empl...     0.229    0.667
# 3    Horrified by ISIL influence in attack in NY. A...     0.000    0.645
# 2    RT @Michell43913024: @CNN @mkraju Sarah Slande...     0.097    0.787
# 0        @CNN Of course, no surprise, it's his nature.     0.204    0.583
# 104  RT @FoxNews: Watch @IngrahamAngle's monologue:...     0.000    0.868
# 105  How EVOLVED are your views on Religion? Take t...     0.000    1.000
# 1    How EVOLVED are your views on Religion? Take t...     0.000    1.000
# 100  RT @tamaragitt: .@FoxNews can confirm: NYC att...     0.000    0.789
# 102  RT @FoxNews: One World Trade Center is lit in ...     0.206    0.613
# 103  RT @WalshFreedom: I just heard @FoxNews call i...     0.000    0.679
# 101  RT @FoxNews: BREAKING: President #Trump says h...     0.113    0.606
#
#      Negative  Compound
# 399     0.268   -0.6597
# 398     0.000    0.5719
# 397     0.000    0.0000
# 396     0.000    0.0000
# 395     0.155   -0.2960
# 394     0.000    0.0000
# 393     0.000    0.4767
# 392     0.000    0.6369
# 391     0.000    0.3612
# 390     0.000    0.0000
# 389     0.000    0.0000
# 388     0.000    0.0000
# 387     0.000    0.0000
# 386     0.000    0.0000
# 385     0.000    0.0000
# 384     0.000    0.0000
# 383     0.000    0.1280
# 382     0.000    0.1280
# 381     0.000    0.0000
# 380     0.000    0.1280
# 379     0.000    0.0000
# 378     0.471   -0.8316
# 377     0.000    0.1280
# 376     0.000    0.1280
# 375     0.000    0.1280
# 374     0.000    0.1280
# 373     0.000    0.1280
# 372     0.000    0.1280
# 371     0.000    0.0000
# 370     0.000    0.1280
# ..        ...       ...
# 117     0.000    0.3089
# 116     0.104   -0.2960
# 119     0.435   -0.9163
# 10      0.134   -0.4767
# 9       0.314   -0.8588
# 8       0.000    0.0000
# 115     0.000    0.0000
# 114     0.172   -0.4404
# 113     0.000    0.0000
# 7       0.119   -0.3182
# 111     0.000    0.4404
# 110     0.000    0.3089
# 6       0.000    0.7906
# 112     0.000    0.0000
# 109     0.200   -0.3818
# 108     0.000    0.3089
# 107     0.263   -0.6705
# 5       0.134   -0.4767
# 106     0.000    0.0000
# 4       0.105    0.3818
# 3       0.355   -0.8875
# 2       0.116   -0.1280
# 0       0.214   -0.0258
# 104     0.132   -0.4939
# 105     0.000    0.0000
# 1       0.000    0.0000
# 100     0.211   -0.7096
# 102     0.181    0.2263
# 103     0.321   -0.8591
# 101     0.281   -0.5994
#
# [500 rows x 8 columns]

# %%
counter1=0
counter2=0
counter3=0
counter4=0
counter5=0

for index, row in df.iterrows():
    if (row["Network"]=="@CNN"):
        counter1 = counter1+1
        CNN = plt.scatter(counter1,row["Compound"],c ='r',marker="o")
    if (row["Network"]=="@NYT"):
        counter2 = counter2+1
        NYT = plt.scatter(counter2,row["Compound"],c ='y',marker="o")
    if (row["Network"]=="@FoxNews"):
        counter3 = counter3+1
        FOX = plt.scatter(counter3,row["Compound"],c ='b',marker="o")
    if (row["Network"]=="@BBC"):
        counter4 = counter4+1
        BBC = plt.scatter(counter4,row["Compound"],c ='cyan',marker="o")
    if (row["Network"]=="@CBS"):
        counter5 = counter5+1
        CBS = plt.scatter(counter5,row["Compound"],c ='g',marker="o")
        
plt.xlabel("Tweets Ago")
plt.ylabel("Tweet Polarity")
plt.title("Sentiment Analysis of Media Tweets (9/21)")
plt.legend(handles = [CNN,BBC,NYT,FOX,CBS], labels = ["CNN","BBC","NYT","FOX","CBS"], loc='center left', bbox_to_anchor=(1, 0.5))

sns.set
plt.show()

# %%
new_df = pd.DataFrame(df.groupby("Network")["Compound"].mean())
new_df
# Out:
#           Compound
# Network
# @BBC     -0.069230
# @CBS      0.041605
# @CNN     -0.167640
# @FoxNews -0.163656
# @NYT     -0.086801

# %%
x_axis = np.arange(len(new_df["Compound"]))
compound_score = new_df["Compound"]
tick_locations = [value+0.4 for value in x_axis]
plt.xticks(tick_locations, ["BBC", "CBS", "CNN", "FOX", "NYT"])
plt.bar(x_axis, compound_score, color = ['cyan','g','r','b','y'], alpha=0.5, align="edge")
plt.xlabel("Networks")
plt.ylabel("Tweet Polarity")
plt.title("Overall Media Sentiment Based on Twitter (9/21)")
sns.set()
plt.show()
